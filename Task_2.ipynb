# %%
pip install -q -U google-generativeai

# %%
#API_KEY
#AIzaSyAfSP-BZ0b38Bxs7jT-NVi1sTKmYOtvsaY

# %%
import google.generativeai as genai
import os
os.environ['GOOGLE_API_KEY']="AIzaSyAfSP-BZ0b38Bxs7jT-NVi1sTKmYOtvsaY"
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# %%
for m in genai.list_models():
    if 'generation' in m.supported_generation_methods:
      print(m.name)

# %%
m.name
# Out:
# 'models/aqa'

# %%
model = genai.GenerativeModel("gemini-1.5-flash")
response = model.generate_content("Write a email to my HR to grant me a sick leave", stream = True)

# %%
for chunk in response:
  print(chunk.text)
  print("_"*80)
# Out:
# ## Subject: Sick
# ________________________________________________________________________________
#  Leave Request - [Your Name]
#
# Dear [HR Contact Name],
#
# This email
# ________________________________________________________________________________
#  is to request a sick leave from [Start Date] to [End Date]. I
# ________________________________________________________________________________
#  am currently experiencing [briefly describe your symptoms] and require time off to recover. I will be unable to work during this period.
#
# I will be checking my email periodically
# ________________________________________________________________________________
#  for urgent matters.
#
# Thank you for your understanding.
#
# Sincerely,
#
# [Your Name]
# [Your Employee ID]
#
# ________________________________________________________________________________

# %%
#when streaming, some response attributes are not available until you've iterated through all the response chunks. this is demonstrated below:

# %%
response = model.generate_content("What is the meaning of life?", stream = True)

# %%
#the prompt_feedback attribute works

# %%
response.prompt_feedback

# %%
#but attributes like text do not:

# %%
try:
  response.text
except Exception as e:
  print(f'{type(e).__name__}: {e}')
# Out:
# IncompleteIterationError: Please let the response complete iteration before accessing the final accumulated
# attributes (or call `response.resolve()`)

# %%
#Generate Text from Image and text inputs

# %%
import PIL.Image

model = genai.GenerativeModel("gemini-1.5-flash")
organ = PIL.Image.open("/content/History of space exploration.jpg")
response = model.generate_content(["Tell me about the earth", organ])
print(response.text)
# Out:
# The image shows a diagram of the solar system with all of the planets and some of their moons.  It also shows some asteroids and other celestial bodies.
#
# The Earth is the third planet from the Sun and is shown as a blue and green sphere. It has one moon, which is shown as a smaller sphere orbiting the Earth.
#
# The Earth is a very special planet because it is the only one known to support life. It has a perfect balance of water, land, and atmosphere that allows for a wide variety of plants and animals to thrive.
#
# Here are some key facts about Earth:
#
# * **Diameter:** 12,742 km
# * **Mass:** 5.972 × 10^24 kg
# * **Distance from the Sun:** 149.6 million km
# * **Orbital period:** 365.25 days
# * **Rotation period:** 23.93 hours
#
# Earth is a fascinating and complex planet, and scientists are constantly learning new things about it.
